# %%
import pandas as pd
import numpy as np
import os

# %%
train_file_path="C:/Users/idubey/DataScience/data/raw/train.csv"
test_file_path="C:/Users/idubey/DataScience/data/raw/test.csv"

# %%
train_df=pd.read_csv(train_file_path,index_col="PassengerId")
test_df=pd.read_csv(test_file_path,index_col="PassengerId")

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
test_df["Survived"]=-888 #Adding a cloumn with default value

# %%
df=pd.concat((train_df,test_df),axis=0) #axis 0 will join by row and 1 wil by vertical
# Out:
# C:\Users\idubey\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# ...

# %%
df.head(10)
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# ...

# %%
df.tail()
# Out:
#               Age Cabin Embarked      Fare                          Name  \
# PassengerId
# 1305          NaN   NaN        S    8.0500            Spector, Mr. Woolf
# 1306         39.0  C105        C  108.9000  Oliva y Ocana, Dona. Fermina
# 1307         38.5   NaN        S    7.2500  Saether, Mr. Simon Sivertsen
# 1308          NaN   NaN        S    8.0500           Ware, Mr. Frederick
# 1309          NaN   NaN        C   22.3583      Peter, Master. Michael J
#
#              Parch  Pclass     Sex  SibSp  Survived              Ticket
# PassengerId
# 1305             0       3    male      0      -888           A.5. 3236
# 1306             0       1  female      0      -888            PC 17758
# 1307             0       3    male      0      -888  SOTON/O.Q. 3101262
# 1308             0       3    male      0      -888              359309
# 1309             1       3    male      1      -888                2668

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
# 8                          Palsson, Master. Gosta Leonard
# 9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                        Sandstrom, Miss. Marguerite Rut
# 12                               Bonnell, Miss. Elizabeth
# 13                         Saundercock, Mr. William Henry
# 14                            Andersson, Mr. Anders Johan
# 15                   Vestrom, Miss. Hulda Amanda Adolfina
# 16                       Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
df[['Name','Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...

# %%
df.loc[5:10,] #Use loc function to index rows and columns. Format is loc[Rows,Columns].
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2
#
#                 Sex  SibSp  Survived  Ticket
# PassengerId
# ...

# %%
df.loc[5:10,'Age':'Pclass']
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass
# PassengerId
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2

# %%
df.loc[5:10,['Age','Pclass','Fare']]#Can use individual column names as well.
# Out:
#               Age  Pclass     Fare
# PassengerId
# 5            35.0       3   8.0500
# 6             NaN       3   8.4583
# 7            54.0       1  51.8625
# 8             2.0       3  21.0750
# 9            27.0       3  11.1333
# 10           14.0       2  30.0708

# %%
#Use iloc to use indexing based on column numbers
df.iloc[5:10,3:8]
# Out:
#                 Fare                                               Name  \
# PassengerId
# 6             8.4583                                   Moran, Mr. James
# 7            51.8625                            McCarthy, Mr. Timothy J
# 8            21.0750                     Palsson, Master. Gosta Leonard
# 9            11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10           30.0708                Nasser, Mrs. Nicholas (Adele Achem)
#
#              Parch  Pclass     Sex
# PassengerId
# 6                0       3    male
# 7                0       1    male
# 8                1       3    male
# 9                2       3  female
# 10               0       2  female

# %%
male_passengers=df.loc[df.Sex=='male',:]
print(len(male_passengers))
# Out:
# 843

# %%
male_passengers=df.loc[(df.Sex=='male') & (df.Pclass==1),:]
print(len(male_passengers))
# Out:
# 179

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                Age         Fare        Parch       Pclass        SibSp  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027     2.294882     0.498854
# std      14.413493    51.758668     0.865560     0.837836     1.041658
# min       0.170000     0.000000     0.000000     1.000000     0.000000
# 25%      21.000000     7.895800     0.000000     2.000000     0.000000
# 50%      28.000000    14.454200     0.000000     3.000000     0.000000
# 75%      39.000000    31.275000     0.000000     3.000000     1.000000
# max      80.000000   512.329200     9.000000     3.000000     8.000000
#
#           Survived
# count  1309.000000
# mean   -283.301757
# std     414.337413
# min    -888.000000
# 25%    -888.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
print('Mean Fare: {0}'.format(df.Fare.mean()))
print('Median Fare: {0}'.format(df.Fare.median()))
# Out:
# Mean Fare: 33.2954792813456
# Median Fare: 14.4542

# %%
# Also df.Fare has min, max, variance, standard Deviation and quantile(0.25/0.5/0.75) for 25th, 50th and 75th percentile.

# %%
# %matplotlib inline #Required to view plots inside notebook.
# Out:
# UsageError: unrecognized arguments: #Required to view plots inside notebook.

# %%
df.Fare.plot(kind='box')

# %%
df.describe(include='all') #Includes categorical count as well.
# Out:
#                 Age        Cabin Embarked         Fare              Name  \
# count   1046.000000          295     1307  1308.000000              1309
# unique          NaN          186        3          NaN              1307
# top             NaN  C23 C25 C27        S          NaN  Kelly, Mr. James
# freq            NaN            6      914          NaN                 2
# mean      29.881138          NaN      NaN    33.295479               NaN
# std       14.413493          NaN      NaN    51.758668               NaN
# min        0.170000          NaN      NaN     0.000000               NaN
# 25%       21.000000          NaN      NaN     7.895800               NaN
# 50%       28.000000          NaN      NaN    14.454200               NaN
# 75%       39.000000          NaN      NaN    31.275000               NaN
# max       80.000000          NaN      NaN   512.329200               NaN
#
#               Parch       Pclass   Sex        SibSp     Survived    Ticket
# ...

# %%
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts(normalize="True")
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
df[df.Survived!=-888].Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts().plot(kind='bar')

# %%
# title:to set title, color: to set color, rot: to set rotation of x axis and ; to remove hexa text
df.Pclass.value_counts().plot(kind='bar',rot=0, title='Class wise count', color='c');

# %% [markdown]
# # Distributions

# %%
df.Age.plot(kind='hist',title='Histogram for Age',color='c');

# %%
df.Age.plot(kind='hist',title='Histogram for Age',color='c',bins=20);

# %%
df.Age.plot(kind='kde',title='Density for Age',color='c');

# %%
print(df.Age.skew()) #Value of skewness
# Out:
# 0.40767455974362266

# %%
df.plot.scatter(x='Age',y='Fare',alpha='0.15')

# %%
df.plot.scatter(x='Pclass',y='Fare',alpha='0.15');

# %% [markdown]
# # Data Munging

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Embarked.isnull()]
# Out:
#               Age Cabin Embarked  Fare  \
# PassengerId
# 62           38.0   B28      NaN  80.0
# 830          62.0   B28      NaN  80.0
#
#                                                   Name  Parch  Pclass     Sex  \
# PassengerId
# 62                                 Icard, Miss. Amelie      0       1  female
# 830          Stone, Mrs. George Nelson (Martha Evelyn)      0       1  female
#
#              SibSp  Survived  Ticket
# PassengerId
# 62               0         1  113572
# 830              0         1  113572

# %%
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].Embarked)
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
# We can fill the Embarked coloumn with value S as it has the highest no. of survivers.
#df.loc[df.Embarked.isnull(),'Embarked']='S' or
#df.Embarked.fillna('S',inplace=True)

# %%
#Exploring the fare for each embarkment point
df.groupby(['Pclass','Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
df.Embarked.fillna('C',inplace=True)

# %%
df[df.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
#Filling out fare
df[df.Fare.isnull()]
# Out:
#               Age Cabin Embarked  Fare                Name  Parch  Pclass  \
# PassengerId
# 1044         60.5   NaN        S   NaN  Storey, Mr. Thomas      0       3
#
#               Sex  SibSp  Survived Ticket
# PassengerId
# 1044         male      0      -888   3701

# %%
median_fare=df.loc[(df.Embarked=='S')&(df.Pclass==3),'Fare'].median()
print(median_fare)
# Out:
# 8.05

# %%
df.Fare.fillna(8.05,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
#Filling out Age
pd.options.display.max_rows=15

# %%
df[df.Age.isnull()]
# Out:
#              Age Cabin Embarked      Fare  \
# PassengerId
# 6            NaN   NaN        Q    8.4583
# 18           NaN   NaN        S   13.0000
# 20           NaN   NaN        C    7.2250
# 27           NaN   NaN        C    7.2250
# 29           NaN   NaN        Q    7.8792
# 30           NaN   NaN        S    7.8958
# 32           NaN   B78        C  146.5208
# ...          ...   ...      ...       ...
# 1274         NaN   NaN        S   14.5000
# 1276         NaN   NaN        S   12.8750
# 1300         NaN   NaN        Q    7.7208
# 1302         NaN   NaN        Q    7.7500
# 1305         NaN   NaN        S    8.0500
# 1308         NaN   NaN        S    8.0500
# 1309         NaN   NaN        C   22.3583
#
#                                                        Name  Parch  Pclass  \
# PassengerId
# 6                                          Moran, Mr. James      0       3
# 18                             Williams, Mr. Charles Eugene      0       2
# ...

# %%
df.Age.plot(kind='hist',bins=20);

# %%
df.Age.mean() #Can fill using mean but not recommended due to extreme values.
# Out:
# 29.881137667304014

# %%
#Replacing with median age of gender
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df[df.Age.notnull()].boxplot('Age','Sex');

# %%
#median_age_gender=df.groupby('Sex').Age.transform('median') #Median age of every gender.
#to fill use df.Age.fillna(median_age_gender,inplace=True)

# %%
df[df.Age.notnull()].boxplot('Age','Pclass');

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
#                               ...
# 1303      Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1304                       Henriksson, Miss. Jenny Lovisa
# 1305                                   Spector, Mr. Woolf
# 1306                         Oliva y Ocana, Dona. Fermina
# 1307                         Saether, Mr. Simon Sivertsen
# 1308                                  Ware, Mr. Frederick
# 1309                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
def GetTitle(name):
    first_name=name.split(',')[1] #Split based on comma
    title_from_name=first_name.split('.')[0] #Split based on dot
    title=title_from_name.strip().lower() #Remove the whitespaces
    return title

# %%
df.Name.map(lambda x: GetTitle(x))
# Out:
# PassengerId
# 1           mr
# 2          mrs
# 3         miss
# 4          mrs
# 5           mr
# 6           mr
# 7           mr
#          ...
# 1303       mrs
# 1304      miss
# 1305        mr
# 1306      dona
# 1307        mr
# 1308        mr
# 1309    master
# Name: Name, Length: 1309, dtype: object

# %%
df.Name.map(lambda x: GetTitle(x)).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'don', 'rev', 'dr', 'mme', 'ms',
#        'major', 'lady', 'sir', 'mlle', 'col', 'capt', 'the countess',
#        'jonkheer', 'dona'], dtype=object)

# %%
#Creating custom titiles
def GetTitle(name):
    title_group={'mr':'Mr',
                 'mrs':'Mrs',
                 'miss':'Miss',
                 'master':'Master',
                 'don':'Sir',
                 'rev':'Sir',
                 'dr':'Officer',
                 'mme':'Mrs',
                 'ms':'Mrs',
                 'major':'Major',
                 'lady':'Lady',
                 'sir':'Sir',
                 'mlle':'Miss',
                 'col':'Officer',
                 'capt':'Officer',
                 'the countess':'Lady',
                 'jonkheer':'Sir',
                 'dona':'Lady'}
    first_name=name.split(',')[1] #Split based on comma
    title_from_name=first_name.split('.')[0] #Split based on dot
    title=title_from_name.strip().lower() #Remove the whitespaces
    return title_group[title]

# %%
df['Title']=df.Name.map(lambda x: GetTitle(x))

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title
# PassengerId
# 1              male      1         0         A/5 21171    Mr
# 2            female      1         1          PC 17599   Mrs
# ...

# %%
df[df.Age.notnull()].boxplot('Age','Title');

# %%
title_age_median=df.groupby('Title').Age.transform('median')
df.Age.fillna(title_age_median,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# Title       1309 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 172.9+ KB

# %% [markdown]
# # Outliers

# %%
df.Age.plot(kind='hist',bins=20);

# %%
df.loc[df.Age>70]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 97           71.0    A5        C  34.6542
# 117          70.5   NaN        Q   7.7500
# 494          71.0   NaN        C  49.5042
# 631          80.0   A23        S  30.0000
# 852          74.0   NaN        S   7.7750
# 988          76.0   C46        S  78.8500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 97                                   Goldschmidt, Mr. George B      0       1
# 117                                       Connors, Mr. Patrick      0       3
# 494                                    Artagaveytia, Mr. Ramon      0       1
# 631                       Barkworth, Mr. Algernon Henry Wilson      0       1
# 852                                        Svensson, Mr. Johan      0       3
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...      0       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# ...

# %%
df.Fare.plot(kind='hist',bins=20)

# %%
df.Fare.plot(kind='box')

# %%
df.loc[df.Fare==df.Fare.max()]
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 259          35.0          NaN        C  512.3292
# 680          36.0  B51 B53 B55        C  512.3292
# 738          35.0         B101        C  512.3292
# 1235         58.0  B51 B53 B55        C  512.3292
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 259                                           Ward, Miss. Anna      0       1
# 680                         Cardeza, Mr. Thomas Drake Martinez      1       1
# 738                                     Lesurer, Mr. Gustave J      0       1
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...      1       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# 259          female      0         1  PC 17755  Miss
# 680            male      0         1  PC 17755    Mr
# 738            male      0         1  PC 17755    Mr
# 1235         female      0      -888  PC 17755   Mrs

# %%
#Reducing skewness using log
Log_fare=np.log(df.Fare+1.0) #adding 1 to ensure 0 fare

# %%
Log_fare.plot(kind='hist',bins=20);

# %%
#Binning
pd.qcut(df.Fare,4)
# Out:
# PassengerId
# 1         (-0.001, 7.896]
# 2       (31.275, 512.329]
# 3         (7.896, 14.454]
# 4       (31.275, 512.329]
# 5         (7.896, 14.454]
# 6         (7.896, 14.454]
# 7       (31.275, 512.329]
#               ...
# 1303    (31.275, 512.329]
# 1304      (-0.001, 7.896]
# 1305      (7.896, 14.454]
# 1306    (31.275, 512.329]
# 1307      (-0.001, 7.896]
# 1308      (7.896, 14.454]
# 1309     (14.454, 31.275]
# Name: Fare, Length: 1309, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.896] < (7.896, 14.454] < (14.454, 31.275] < (31.275, 512.329]]

# %%
#Discretization
pd.qcut(df.Fare,4,labels=['very_low','low','high','very_high'])
# Out:
# PassengerId
# 1        very_low
# 2       very_high
# 3             low
# 4       very_high
# 5             low
# 6             low
# 7       very_high
#           ...
# 1303    very_high
# 1304     very_low
# 1305          low
# 1306    very_high
# 1307     very_low
# 1308          low
# 1309         high
# Name: Fare, Length: 1309, dtype: category
# Categories (4, object): [very_low < low < high < very_high]

# %%
pd.qcut(df.Fare,4,labels=['very_low','low','high','very_high']).value_counts().plot(kind='bar');

# %%
df['Fare_Bin']=pd.qcut(df.Fare,4,labels=['very_low','low','high','very_high'])

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title   Fare_Bin
# PassengerId
# 1              male      1         0         A/5 21171    Mr   very_low
# ...

# %% [markdown]
# # Feature Engineering

# %%
#Creating age state feature
df['AgeState']=np.where(df['Age']>=18,'Adult','Child')

# %%
df.AgeState.value_counts()
# Out:
# Adult    1147
# Child     162
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0           495     54
# 1           279     63

# %%
#Creating family size
df['FamilySize']=df.Parch+df.SibSp+1

# %%
df.FamilySize.plot(kind='hist');

# %%
df.loc[df.FamilySize==df.FamilySize.max(),['Name','Survived','FamilySize','Ticket']]
# Out:
#                                           Name  Survived  FamilySize    Ticket
# PassengerId
# 160                 Sage, Master. Thomas Henry         0          11  CA. 2343
# 181               Sage, Miss. Constance Gladys         0          11  CA. 2343
# 202                        Sage, Mr. Frederick         0          11  CA. 2343
# 325                   Sage, Mr. George John Jr         0          11  CA. 2343
# 793                    Sage, Miss. Stella Anna         0          11  CA. 2343
# 847                   Sage, Mr. Douglas Bullen         0          11  CA. 2343
# 864          Sage, Miss. Dorothy Edith "Dolly"         0          11  CA. 2343
# 1080                           Sage, Miss. Ada      -888          11  CA. 2343
# 1234                     Sage, Mr. John George      -888          11  CA. 2343
# 1252               Sage, Master. William Henry      -888          11  CA. 2343
# 1257            Sage, Mrs. John (Annie Bullen)      -888          11  CA. 2343

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].FamilySize)
# Out:
# FamilySize   1   2   3   4   5   6   7   8   11
# Survived
# 0           374  72  43   8  12  19   8   6   7
# 1           163  89  59  21   3   3   4   0   0

# %%
#Motherhood check
df['IsMother']=np.where(((df.Sex=='female')&(df.Parch>0)&(df.Age>18)&(df.Title!='Miss')),1,0)

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title   Fare_Bin  \
# PassengerId
# 1              male      1         0         A/5 21171    Mr   very_low
# ...

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].IsMother)
# Out:
# IsMother    0   1
# Survived
# 0         533  16
# 1         303  39

# %%
df.Cabin
# Out:
# PassengerId
# 1        NaN
# 2        C85
# 3        NaN
# 4       C123
# 5        NaN
# 6        NaN
# 7        E46
#         ...
# 1303     C78
# 1304     NaN
# 1305     NaN
# 1306    C105
# 1307     NaN
# 1308     NaN
# 1309     NaN
# Name: Cabin, Length: 1309, dtype: object

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.loc[df.Cabin=='T']
# Out:
#               Age Cabin Embarked  Fare                          Name  Parch  \
# PassengerId
# 340          45.0     T        S  35.5  Blackwell, Mr. Stephen Weart      0
#
#              Pclass   Sex  SibSp  Survived  Ticket Title   Fare_Bin AgeState  \
# PassengerId
# 340               1  male      0         0  113784    Mr  very_high    Adult
#
#              FamilySize  IsMother
# PassengerId
# 340                   1         0

# %%
df.loc[df.Cabin=='T','Cabin']=np.NaN

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34',
#        'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37',
#        'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39',
#        'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41',
#        'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58',
# ...

# %%
#Creating deck Z for NaN
def get_deck(cabin):
    return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
df['Deck']=df['Cabin'].map(lambda x: get_deck(x))

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].Deck)
# Out:
# Deck      A   B   C   D   E  F  G    Z
# Survived
# 0         8  12  24   8   8  5  2  482
# 1         7  35  35  25  24  8  2  206

# %%
df.Deck.value_counts()
# Out:
# Z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: Deck, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 17 columns):
# Age           1309 non-null float64
# Cabin         294 non-null object
# Embarked      1309 non-null object
# Fare          1309 non-null float64
# Name          1309 non-null object
# Parch         1309 non-null int64
# Pclass        1309 non-null int64
# Sex           1309 non-null object
# SibSp         1309 non-null int64
# Survived      1309 non-null int64
# Ticket        1309 non-null object
# Title         1309 non-null object
# Fare_Bin      1309 non-null category
# AgeState      1309 non-null object
# FamilySize    1309 non-null int64
# IsMother      1309 non-null int32
# Deck          1309 non-null object
# dtypes: category(1), float64(2), int32(1), int64(5), object(8)
# memory usage: 210.2+ KB

# %%
#Categorical Feature Encoding
df['IsMale']=np.where(df.Sex=='male',1,0)

# %%
df=pd.get_dummies(df,columns=['Deck','Pclass','Title','Fare_Bin','Embarked','AgeState'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 40 columns):
# Age                   1309 non-null float64
# Cabin                 294 non-null object
# Fare                  1309 non-null float64
# Name                  1309 non-null object
# Parch                 1309 non-null int64
# Sex                   1309 non-null object
# SibSp                 1309 non-null int64
# Survived              1309 non-null int64
# Ticket                1309 non-null object
# FamilySize            1309 non-null int64
# IsMother              1309 non-null int32
# IsMale                1309 non-null int32
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# Deck_Z                1309 non-null uint8
# ...

# %%
#Dropping Columns
df.drop(['Cabin','Name','Ticket','Parch','SibSp','Sex'],axis=1,inplace=True)

# %%
columns=[column for column in df.columns if column != 'Survived']
columns=['Survived']+columns
df=df[columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 34 columns):
# Survived              1309 non-null int64
# Age                   1309 non-null float64
# Fare                  1309 non-null float64
# FamilySize            1309 non-null int64
# IsMother              1309 non-null int32
# IsMale                1309 non-null int32
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# Deck_Z                1309 non-null uint8
# Pclass_1              1309 non-null uint8
# Pclass_2              1309 non-null uint8
# Pclass_3              1309 non-null uint8
# Title_Lady            1309 non-null uint8
# Title_Major           1309 non-null uint8
# Title_Master          1309 non-null uint8
# ...

# %%
df.loc[df.Fare.isnull(),]
# Out:
# Empty DataFrame
# Columns: [Survived, Age, Fare, FamilySize, IsMother, IsMale, Deck_A, Deck_B, Deck_C, Deck_D, Deck_E, Deck_F, Deck_G, Deck_Z, Pclass_1, Pclass_2, Pclass_3, Title_Lady, Title_Major, Title_Master, Title_Miss, Title_Mr, Title_Mrs, Title_Officer, Title_Sir, Fare_Bin_very_low, Fare_Bin_low, Fare_Bin_high, Fare_Bin_very_high, Embarked_C, Embarked_Q, Embarked_S, AgeState_Adult, AgeState_Child]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# # Saving Processed Data

# %%
processed_data_path=os.path.join(os.path.pardir,'data','processed')
write_train_path=os.path.join(processed_data_path,'train.csv')
write_test_path=os.path.join(processed_data_path,'test.csv')

# %%
#train data
df.loc[df.Survived!=-888].to_csv(write_train_path)
#test data
columns=[column for column in df.columns if column!='Survived']
df.loc[df.Survived==-888,columns].to_csv(write_test_path)
